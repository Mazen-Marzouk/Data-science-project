# %% [markdown]
# # **Introduction**
# This data set contains information about soccer matches, players, and teams from several European countries from 2008 to 2016.

# %% [markdown]
# # **Questions**
# *we want to know:*
#
# 1 - which season is the most season in scoring goals?
#
# 2- which country(England or Belgium)have more match_api_id?

# %% [markdown]
# # **Importing Libraries**

# %%
import pandas as pd #import pandas
import numpy as np  #import numpy
import matplotlib.pyplot as plt #import matplotlib
import seaborn as sns #import seaborn

# %% [markdown]
# # **Invistigate File**

# %%
match_data = pd.read_csv("Match.csv")
# this code read file ("Match.csv") and save in path could (match_data)

# %% [markdown]
# #**Define Function**

# %%
def barplot(x, y, data=match_data):
    sns.barplot(x=x , y=y , data=match_data)
    plt.title(f"Comparision between {x} and {y}")
    plt.xlabel(x)
    plt.ylabel(y)
    plt.show()
#Define Function to make barplot

# %% [markdown]
# # **Showind Data**

# %%
match_data.head()
# this show the first 5 rows of data
# Out:
#    id country_id               league_id     season  stage             date  \
# 0   1    Belgium  Belgium Jupiler League  2008/2009      1  17/08/2008 0:00
# 1   2    Belgium  Belgium Jupiler League  2008/2009      1  16/08/2008 0:00
# 2   3    Belgium  Belgium Jupiler League  2008/2009      1  16/08/2008 0:00
# 3   4    Belgium  Belgium Jupiler League  2008/2009      1  17/08/2008 0:00
# 4   5    Belgium  Belgium Jupiler League  2008/2009      1  16/08/2008 0:00
#
#    match_api_id   home_team_api_id   away_team_api_id  home_team_goal  ...  \
# 0        492473           KRC Genk       Beerschot AC               1  ...
# 1        492474   SV Zulte-Waregem   Sporting Lokeren               0  ...
# 2        492475  KSV Cercle Brugge     RSC Anderlecht               0  ...
# 3        492476           KAA Gent          RAEC Mons               5  ...
# 4        492477      FCV Dender EH  Standard de Liège               1  ...
#
# ...

# %% [markdown]
# # **Showing info About Data**

# %%
match_data.info() #show information about each column in data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 85 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   country_id        25979 non-null  object
#  2   league_id         25979 non-null  object
#  3   season            25979 non-null  object
#  4   stage             25979 non-null  int64
#  5   date              25979 non-null  object
#  6   match_api_id      25979 non-null  int64
#  7   home_team_api_id  25979 non-null  object
#  8   away_team_api_id  25979 non-null  object
#  9   home_team_goal    25979 non-null  int64
#  10  away_team_goal    25979 non-null  int64
#  11  home_player_X1    24158 non-null  float64
#  12  home_player_X2    24158 non-null  float64
#  13  home_player_X3    24147 non-null  float64
#  14  home_player_X4    24147 non-null  float64
#  15  home_player_X5    24147 non-null  float64
# ...

# %% [markdown]
# # **Checkig NUN Values**

# %%
match_data.isna().sum() #check nun values and where they are located
# Out:
# id                0
# country_id        0
# league_id         0
# season            0
# stage             0
#               ...
# foulcommit    11762
# card          11762
# cross         11762
# corner        11762
# possession    11762
# Length: 85, dtype: int64

# %% [markdown]
# *thier is 28071 nun in the data*

# %% [markdown]
# # **Checking Duplicates**

# %%
match_data.duplicated().sum() #check duplicates
# Out:
# 0

# %% [markdown]
# *No duplicates in this data*

# %% [markdown]
# # **Showing Describe Of Data**

# %%
match_data.describe() #show more information about each column
# Out:
#                  id         stage  match_api_id  home_team_goal  \
# count  25979.000000  25979.000000  2.597900e+04    25979.000000
# mean   12990.000000     18.242773  1.195429e+06        1.544594
# std     7499.635658     10.407354  4.946279e+05        1.297158
# min        1.000000      1.000000  4.831290e+05        0.000000
# 25%     6495.500000      9.000000  7.684365e+05        1.000000
# 50%    12990.000000     18.000000  1.147511e+06        1.000000
# 75%    19484.500000     27.000000  1.709852e+06        2.000000
# max    25979.000000     38.000000  2.216672e+06       10.000000
#
#        away_team_goal  home_player_X1  home_player_X2  home_player_X3  \
# count    25979.000000    24158.000000    24158.000000    24147.000000
# mean         1.160938        0.999586        2.073516        4.061001
# std          1.142110        0.022284        0.387185        0.385973
# min          0.000000        0.000000        0.000000        1.000000
# ...

# %% [markdown]
# # ***Cleaning***

# %%
match_data_clened = match_data.fillna(match_data.median) #change nan values to values depending on median

# %%
match_data_clened.isna().sum() #check that there isn't any nun values
# Out:
# id            0
# country_id    0
# league_id     0
# season        0
# stage         0
#              ..
# foulcommit    0
# card          0
# cross         0
# corner        0
# possession    0
# Length: 85, dtype: int64

# %%
match_data_clened.info() #check that information of all columns are complete
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25979 entries, 0 to 25978
# Data columns (total 85 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                25979 non-null  int64
#  1   country_id        25979 non-null  object
#  2   league_id         25979 non-null  object
#  3   season            25979 non-null  object
#  4   stage             25979 non-null  int64
#  5   date              25979 non-null  object
#  6   match_api_id      25979 non-null  int64
#  7   home_team_api_id  25979 non-null  object
#  8   away_team_api_id  25979 non-null  object
#  9   home_team_goal    25979 non-null  int64
#  10  away_team_goal    25979 non-null  int64
#  11  home_player_X1    25979 non-null  object
#  12  home_player_X2    25979 non-null  object
#  13  home_player_X3    25979 non-null  object
#  14  home_player_X4    25979 non-null  object
#  15  home_player_X5    25979 non-null  object
# ...

# %% [markdown]
# Now we remove all nun values and replace it to integers depending on median

# %% [markdown]
# # **EDA**

# %%
sns.barplot(x="match_api_id" ,hue="league_id", data=match_data_clened)
plt.title("Comparision between Leagues")
plt.xlabel("match_api_id")
plt.ylabel("count")
plt.show()
#make barplot to show comparison between Leagues

# %% [markdown]
# Here we find that Portugal League (ZON Sarges) is the most league in match_api

# %%
barplot('home_team_goal','league_id',data=match_data)
#make barplot to show the most league in home_team_goal

# %% [markdown]
# The Netherland Eredivisie is the most league in home_team_goal

# %%
sns.scatterplot(x=match_data_clened["stage"],y=match_data_clened["country_id"],hue=match_data_clened["league_id"])
plt.show()
#make scattershot to show comparison between countries and stages of Leagues

# %% [markdown]
# We find that alot of Leagues are in the same stage as Ligue1(France),Premier League(England),SerieA(Italy),etc..

# %% [markdown]
# #**Conclusion**

# %% [markdown]
# **First**: We show the data and put questions to answer
#
# **Second**: We clean data and replace nun values
#
# **Third**: We make an visual barplots to show data in simple way and compare between things to answer question

# %% [markdown]
# *Limitation*:
#
# 1-The time wasn't enough
#
# 2- Alot of things in data don't work with me
